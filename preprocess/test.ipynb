# %%
import pandas as pd
from inputoutput import Reader
import numpy as np
import datacleaning as dc

# %%
reader = Reader()
df = reader.read_in('../datasets/AppGallery.csv')

# %%
df = dc.rename_headers(df)
df = dc.unnamed_col_handling(df)
print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 df = dc.rename_headers(df)
# ----> 2 df = dc.unnamed_col_handling(df)
#       3 print(df)
#
# File C:\Masters Artificial Intelligence\Semester 1\PycharmProjects\NCI_Projects_Harry_Reynolds\Engineering_Evaluating_AI_Systems\Shanes_git\Engineering_and_Evaluating_Artificial_Intelligence_CA1\preprocess\datacleaning.py:26, in unnamed_col_handling(df)
#      24 for col in unnamed_df.columns:
#      25     unnamed_df_unique = unnamed_df[col].unique()
# ---> 26     if unnamed_df_unique.isna():
#      27         new_list.append(col)
#      30 return new_list
#
# AttributeError: 'numpy.ndarray' object has no attribute 'isna'
