# %%
import pandas as pd
from inputoutput import Reader
import numpy as np
import datacleaning as dc

# %%
reader = Reader()
df = reader.read_in('../datasets/AppGallery.csv')

# %%
df = dc.rename_headers(df)
df = dc.drop_unnamed_cols(df)

df.head(100)
# Out:
#     ticket_id  interaction_id  interaction_date                   mailbox  \
# 0       24310           68365               NaN   support.eu@aspiegel.com
# 1       24075           67730               NaN   support.pt@aspiegel.com
# 2       24075           67762               NaN   support.pt@aspiegel.com
# 3       23748           66706               NaN   support.pt@aspiegel.com
# 4       23740           66684               NaN   support.eu@aspiegel.com
# ..        ...             ...               ...                       ...
# 95      22926           64238       44805.42569  support.es1@aspiegel.com
# 96      22926           64320       44805.53333  support.es1@aspiegel.com
# 97      22926           64322       44805.53611  support.es1@aspiegel.com
# 98      22924           64153       44805.31736   support.eu@aspiegel.com
# 99      22924           64303       44805.51042   support.eu@aspiegel.com
#
#                                        ticket_summary  \
# ...
