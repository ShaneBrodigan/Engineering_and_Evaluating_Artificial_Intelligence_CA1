# %%
import pandas as pd
from io import Reader
import numpy as np

# %%
def read_in(file_path):
    df = pd.read_csv(file_path)
    return df

df = read_in('../datasets/AppGallery.csv')

# %%
df.head(100_000)
#df.info()
# Out:
#      Ticket id  Interaction id  Interaction date                   Mailbox  \
# 0        24310           68365               NaN   support.eu@aspiegel.com
# 1        24075           67730               NaN   support.pt@aspiegel.com
# 2        24075           67762               NaN   support.pt@aspiegel.com
# 3        23748           66706               NaN   support.pt@aspiegel.com
# 4        23740           66684               NaN   support.eu@aspiegel.com
# ..         ...             ...               ...                       ...
# 117      22405           64292       44805.49514   support.eu@aspiegel.com
# 118      22311           64297       44805.50208   support.eu@aspiegel.com
# 119      21011           64226       44805.40625  support.es1@aspiegel.com
# 120      23119           64738               NaN   support.pt@aspiegel.com
# 121      23107           64709               NaN   support.eu@aspiegel.com
#
#                                         Ticket Summary  \
# ...

# %%
reader = Reader()
reader.read_in('../datasets/AppGallery.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 reader = Reader()
#       2 reader.read_in('../datasets/AppGallery.csv')
#
# TypeError: Can't instantiate abstract class Reader without an implementation for abstract method 'read'
